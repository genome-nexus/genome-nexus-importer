# %% [markdown]
# # One gene id per hugo symbol

# %%
import pandas as pd

# %%
et = pd.read_csv("../data/ensembl_biomart_transcripts.txt", sep='\t')

# %%
et_hugo_counts = et.groupby("hgnc_symbol").gene_stable_id.nunique()
et_hugo_counts.head()
# Out:
# hgnc_symbol
# A1BG        1
# A1BG-AS1    1
# A1CF        1
# A2M         1
# A2M-AS1     1
# Name: gene_stable_id, dtype: int64

# %%
len(et_hugo_counts[et_hugo_counts > 1])
# Out:
# 2004

# %%
et_geneid_counts = et.groupby("gene_stable_id").hgnc_symbol.nunique()
et_geneid_counts.head()
# Out:
# gene_stable_id
# ENSG00000000003    1
# ENSG00000000005    1
# ENSG00000000419    1
# ENSG00000000457    1
# ENSG00000000460    1
# Name: hgnc_symbol, dtype: int64

# %%
len(et_geneid_counts[et_geneid_counts > 1])
# Out:
# 70

# %%
et_geneid_counts[et_geneid_counts > 1].head()
# Out:
# gene_stable_id
# ENSG00000109072    2
# ENSG00000199480    2
# ENSG00000199654    2
# ENSG00000207688    2
# ENSG00000207704    2
# Name: hgnc_symbol, dtype: int64

# %%
multiple_ensembl = set(list(et_hugo_counts[et_hugo_counts > 1].index))

# %%
et_hugo_counts[et_hugo_counts > 1].head()
# Out:
# hgnc_symbol
# AADACL2     2
# ABCA11P     2
# ABCB10P4    2
# ABCB11      2
# ABCD1       2
# Name: gene_stable_id, dtype: int64

# %%
len(et_hugo_counts)
# Out:
# 33670

# %%
# !ls ../data
# Out:
# 20180321_hgnc_symbols.txt
# Homo_sapiens.GRCh37.gff3.gz
# Makefile
# ensembl_biomart_canonical_transcripts_per_hgnc.txt
# ensembl_biomart_geneids_grch37.p13.transcript_info.txt
# ensembl_biomart_geneids_grch37.p13.txt
# ensembl_biomart_pfam_grch37.p13.txt
# ensembl_biomart_transcripts.json
# ensembl_biomart_transcripts.json.gz
# ensembl_biomart_transcripts.txt
# ensembl_exon_info.txt
# hgnc.txt
# isoform_overrides_at_mskcc.txt
# isoform_overrides_genome_nexus.txt
# isoform_overrides_uniprot.txt
# oncokb_cancer_genes_list_20170926.txt
# pfamA.txt

# %%
hugo = pd.read_csv("../data/20180321_hgnc_symbols.txt", sep="\t")

# %%
# 1912 of 2004 are approved symbols, so 86 are not approved (maybe synonyms?)
len(hugo[hugo['Approved Symbol'].isin(multiple_ensembl)])
# Out:
# 1912

# %%
# no ensembl id assigned in hgnc website
hugo_override = hugo[hugo['Approved Symbol'].isin(multiple_ensembl)].set_index('Approved Symbol')['Ensembl ID(supplied by Ensembl)']
print("Approved symbols w/o ensembl id in hugo, but multiple in ensembl dump: ", pd.isnull(hugo_override).sum())
# TODO: check whether all these are in ensembl transcripts file
hugo_override[pd.isnull(hugo_override)]
# Out:
# Approved symbols w/o ensembl id in hugo, but multiple in ensembl dump:  17
# Approved Symbol
# AHCYP1        NaN
# CCL4L1        NaN
# CTSLP3        NaN
# DUSP8P1       NaN
# DUSP8P2       NaN
# FAM83H-AS1    NaN
# FAM226A       NaN
# GLUD1P6       NaN
# HIST2H2BC     NaN
# LILRA3        NaN
# RNA5-8S5      NaN
# RNVU1-8       NaN
# RNVU1-11      NaN
# RPL17P42      NaN
# TRBV6-9       NaN
# TRBV7-8       NaN
# VN1R14P       NaN
# Name: Ensembl ID(supplied by Ensembl), dtype: object

# %%
print("{} ensembl ids assigned to hugo symbols from {} total (+ {} w/o assignment) that are not in ensembl transcript dump".format(
    ((~hugo['Ensembl ID(supplied by Ensembl)'].isin(et.gene_stable_id.unique())) & (~(pd.isnull(hugo['Ensembl ID(supplied by Ensembl)'])))).sum(),
    (~pd.isnull(hugo['Ensembl ID(supplied by Ensembl)'])).sum(),
    pd.isnull(hugo['Ensembl ID(supplied by Ensembl)']).sum())
)
# Out:
# 1572 ensembl ids assigned to hugo symbols from 37253 total (+ 8491 w/o assignment) that are not in ensembl transcript dump

# %%
# TODO: check of those without assignemnt if they are in ensembl dump
print("Of the {} ones w/o assignment, there are {} associated transcripts in ensembl dump".format(
    pd.isnull(hugo['Ensembl ID(supplied by Ensembl)']).sum(),
    hugo['Approved Symbol'][pd.isnull(hugo['Ensembl ID(supplied by Ensembl)'])].isin(et.hgnc_symbol).sum()
)
)
# Out:
# Of the 8491 ones w/o assignment, there are 222 associated transcripts in ensembl dump

# %%
# not that many important ones, but good to resolve
hugo[pd.isnull(hugo['Ensembl ID(supplied by Ensembl)']) & (hugo['Approved Symbol'].isin(et.hgnc_symbol))]
# Out:
#           HGNC ID Approved Symbol  \
# 725    HGNC:24620        AHCTF1P1
# 729    HGNC:44993          AHCYP1
# 1143   HGNC:43603     ANKRD20A12P
# 1145   HGNC:43605     ANKRD20A14P
# 1668   HGNC:44201        ARL14EPL
# 1842   HGNC:39401          ASNSP5
# 2113   HGNC:39662        ATP8A2P1
# 2300   HGNC:15732           BAGE5
# 2622   HGNC:19436         BMS1P18
# 2624   HGNC:49153         BMS1P20
# 2759   HGNC:24171          BRD7P3
# 2968   HGNC:32021        C1orf134
# 3111   HGNC:42398           C4B_2
# 3463   HGNC:20358       C14orf144
# 3513   HGNC:28329        C16orf47
# 4098   HGNC:42874          CBX3P2
# 4126   HGNC:45128           CCAT1
# 4314   HGNC:10628          CCL3L1
# 4318   HGNC:10631          CCL4L1
# 5768   HGNC:18623            COG8
# 5861    HGNC:2238        COPG2IT1
# 5975   HGNC:16529         COX7BP1
# 6123   HGNC:26619          CRIPAK
# 6284   HGNC:48359         CSPG4P8
# 6285   HGNC:48360         CSPG4P9
# 6451    HGNC:2541          CTSLP3
# 6738   HGNC:39955        CYP4F31P
# 6740   HGNC:39952        CYP4F33P
# 6746   HGNC:39947        CYP4F59P
# 6748   HGNC:42469        CYP4F61P
# ...           ...             ...
# 38424  HGNC:30356        SNORD38B
# 38483  HGNC:32738         SNORD78
# 38512  HGNC:32766       SNORD103A
# 38513  HGNC:32767       SNORD103B
# 38650  HGNC:33558        SNORD119
# 38844  HGNC:39623        SNX18P15
# 38845  HGNC:39624        SNX18P16
# 40136  HGNC:43898        TAS2R67P
# 41136  HGNC:42967         TMEM247
# 41622  HGNC:12043          TRAJ15
# 41783  HGNC:12213         TRBV3-2
# 41786  HGNC:12217         TRBV4-3
# 41794  HGNC:12225         TRBV5-8
# 41797  HGNC:12228         TRBV6-3
# 41803  HGNC:12234         TRBV6-9
# 41811  HGNC:12242         TRBV7-8
# 43113  HGNC:33870        TXNRD3NB
# 43182  HGNC:12467           UBBP4
# 43882  HGNC:18721         VN1R14P
# 43986  HGNC:33212          VN2R6P
# 43991  HGNC:33217         VN2R11P
# 44139  HGNC:33884          WASH5P
# 44172  HGNC:26250         WBP11P1
# 44381  HGNC:30679          XAGE1C
# 44382  HGNC:21508          XAGE1D
# 44383  HGNC:18372          XAGE1E
# 44497   HGNC:2429          YBX3P1
# 44553  HGNC:49435         YWHAEP6
# 45067  HGNC:28586      ZNF205-AS1
# 45596  HGNC:33265         ZNF818P
#
#                                            Approved Name    Status  \
# 725    AT-hook containing transcription factor 1 pseu...  Approved
# 729                  adenosylhomocysteinase pseudogene 1  Approved
# 1143   ankyrin repeat domain 20 family member A12, ps...  Approved
# 1145   ankyrin repeat domain 20 family member A14, ps...  Approved
# 1668   ADP ribosylation factor like GTPase 14 effecto...  Approved
# 1842                  asparagine synthetase pseudogene 5  Approved
# 2113   ATPase phospholipid transporting 8A2 pseudogene 1  Approved
# 2300                                BAGE family member 5  Approved
# 2622      BMS1, ribosome biogenesis factor pseudogene 18  Approved
# 2624      BMS1, ribosome biogenesis factor pseudogene 20  Approved
# 2759               bromodomain containing 7 pseudogene 3  Approved
# 2968                 chromosome 1 open reading frame 134  Approved
# 3111   complement component 4B (Chido blood group), c...  Approved
# 3463     chromosome 14 open reading frame 144 (putative)  Approved
# 3513                 chromosome 16 open reading frame 47  Approved
# 4098                            chromobox 3 pseudogene 2  Approved
# 4126   colon cancer associated transcript 1 (non-prot...  Approved
# 4314                 C-C motif chemokine ligand 3 like 1  Approved
# 4318                 C-C motif chemokine ligand 4 like 1  Approved
# 5768             component of oligomeric golgi complex 8  Approved
# 5861   COPG2 imprinted transcript 1 (non-protein coding)  Approved
# 5975        cytochrome c oxidase subunit 7B pseudogene 1  Approved
# 6123                        cysteine rich PAK1 inhibitor  Approved
# 6284     chondroitin sulfate proteoglycan 4 pseudogene 8  Approved
# 6285     chondroitin sulfate proteoglycan 4 pseudogene 9  Approved
# 6451                            cathepsin L pseudogene 3  Approved
# 6738   cytochrome P450 family 4 subfamily F member 31...  Approved
# 6740   cytochrome P450 family 4 subfamily F member 33...  Approved
# 6746   cytochrome P450 family 4 subfamily F member 59...  Approved
# 6748   cytochrome P450 family 4 subfamily F member 61...  Approved
# ...                                                  ...       ...
# 38424                   small nucleolar RNA, C/D box 38B  Approved
# 38483                    small nucleolar RNA, C/D box 78  Approved
# 38512                  small nucleolar RNA, C/D box 103A  Approved
# 38513                  small nucleolar RNA, C/D box 103B  Approved
# 38650                   small nucleolar RNA, C/D box 119  Approved
# 38844                     sorting nexin 18 pseudogene 15  Approved
# 38845                     sorting nexin 18 pseudogene 16  Approved
# 40136              taste 2 receptor member 67 pseudogene  Approved
# 41136                          transmembrane protein 247  Approved
# 41622                   T cell receptor alpha joining 15  Approved
# 41783     T cell receptor beta variable 3-2 (pseudogene)  Approved
# 41786                  T cell receptor beta variable 4-3  Approved
# 41794                  T cell receptor beta variable 5-8  Approved
# 41797                  T cell receptor beta variable 6-3  Approved
# 41803                  T cell receptor beta variable 6-9  Approved
# 41811                  T cell receptor beta variable 7-8  Approved
# 43113                   thioredoxin reductase 3 neighbor  Approved
# 43182                           ubiquitin B pseudogene 4  Approved
# 43882               vomeronasal 1 receptor 14 pseudogene  Approved
# 43986                vomeronasal 2 receptor 6 pseudogene  Approved
# 43991               vomeronasal 2 receptor 11 pseudogene  Approved
# 44139            WAS protein family homolog 5 pseudogene  Approved
# 44172          WW domain binding protein 11 pseudogene 1  Approved
# 44381                         X antigen family member 1C  Approved
# 44382                         X antigen family member 1D  Approved
# 44383                         X antigen family member 1E  Approved
# 44497               Y-box binding protein 3 pseudogene 1  Approved
# 44553  tyrosine 3-monooxygenase/tryptophan 5-monooxyg...  Approved
# 45067                             ZNF205 antisense RNA 1  Approved
# 45596                zinc finger protein 818, pseudogene  Approved
#
#                 Previous Symbols                             Synonyms  \
# 725                      AHCTF1P                            ELYS-like
# 729                          NaN                                  NaN
# 1143                         NaN                                  NaN
# 1145                         NaN                                  NaN
# 1668                         NaN                                  NaN
# 1842                         NaN                                  NaN
# 2113                         NaN                                  NaN
# 2300                         NaN                                CT2.5
# 2622         C14orf17, LINC00516                                  NaN
# 2624                         NaN                                  NaN
# 2759                         NaN                                  NaN
# 2968                         NaN                                  NaN
# 3111                         NaN                                  NaN
# 3463                         NaN                                  NaN
# 3513                         NaN                             FLJ26184
# 4098                         NaN                                  NaN
# 4126                         NaN              CARLo-5, onco-lncRNA-40
# 4314   D17S1718, SCYA3L, SCYA3L1                    G0S19-2, LD78BETA
# 4318               SCYA4L, CCL4L                       AT744.2, LAG-1
# 5768                         NaN                       FLJ22315, DOR1
# 5861                         NaN            CIT1, NCRNA00170, COPG2AS
# 5975                         NaN                            bK714B7.1
# 6123                         NaN                             FLJ34443
# 6284                         NaN                                  NaN
# 6285                         NaN                                  NaN
# 6451             CTSLL3, CTSL1P3                                  NaN
# 6738                         NaN                    CYP4F-se10[6:7:8]
# 6740                         NaN                         CYP4F-se6[6]
# 6746                         NaN                      CYP4F-se14[6:8]
# 6748                         NaN                    CYP4F-se16[6:7:8]
# ...                          ...                                  ...
# 38424                     RNU38B                                 U38B
# 38483                        NaN                                  U78
# 38512                        NaN                                 U103
# 38513                        NaN                                U103B
# 38650                        NaN                                  NaN
# 38844                        NaN                                  NaN
# 38845                        NaN                                  NaN
# 40136                        NaN                                  NaN
# 41136                        NaN                                  NaN
# 41622                        NaN                                  NaN
# 41783                        NaN       TRBV32, TCRBV3S2, TCRBV9S2A2PT
# 41786                        NaN      TRBV43, TCRBV4S3, TCRBV7S2A1N4T
# 41794                        NaN        TRBV58, TCRBV5S4A2T, TCRBV5S8
# 41797                        NaN  TRBV63, TCRBV13S9/13S2A1T, TCRBV6S3
# 41803                        NaN          TRBV69, TCRBV13S4, TCRBV6S9
# 41811                        NaN      TRBV78, TCRBV6S2A1N1T, TCRBV7S8
# 43113                  TXNRD3IT1                    TR2IT1, TXNRD3NT1
# 43182                        NaN                                  NaN
# 43882                        NaN        bA457M11.4, hs6M1-5p, VNR6I5P
# 43986                        NaN                                  NaN
# 43991                        NaN                                  NaN
# 44139                        NaN                                  NaN
# 44172                        NaN                              HsT3017
# 44381                        NaN                              CT12.1c
# 44382                        NaN                              CT12.1d
# 44383                        NaN                                  NaN
# 44497                     CSDAP1                                  NaN
# 44553                        NaN                                  NaN
# 45067                        NaN                              MGC3771
# 45596                     ZNF818                             FLJ46385
#
#                               Chromosome   Accession Numbers    RefSeq IDs  \
# 725                               2q24.2                 NaN     NG_002622
# 729                             10q11.22                 NaN     NG_022175
# 1143                                   4                 NaN           NaN
# 1145                            unplaced                 NaN           NaN
# 1668                              5q23.1                 NaN  NM_001195581
# 1842                            unplaced                 NaN           NaN
# 2113                            10p11.21                 NaN     NG_025483
# 2300           13cen, GRCh38 novel patch            AF339516     NM_182484
# 2622                             14q11.2            BC040855           NaN
# 2624                            22q11.22                 NaN           NaN
# 2759                             6q22.31                 NaN     NR_002730
# 2968                             1p36.13            AL109627           NaN
# 3111    6p21.3 alternate reference locus            GL000256  NM_001242823
# 3463                            14q32.33            BC007749           NaN
# 3513                             16q22.3            AK129695           NaN
# 4098                            18p11.32                 NaN           NaN
# 4126                             8q24.21  HM358356, AK125310           NaN
# 4314     17q12 alternate reference locus              X52149     NM_021006
# 4318     17q12 alternate reference locus              X53682  NM_001001435
# 5768                             16q22.1            AK025968     NM_032382
# 5861                                7q32            AF038190     NR_024086
# 5975                             22q12.3            AF042164     NG_001300
# 6123                              4p16.3            AK096209     NM_175918
# 6284                             15q25.2                 NaN           NaN
# 6285   15q25.2 alternate reference locus                 NaN           NaN
# 6451                            10q11.22              L25629     NG_016830
# 6738                              2q21.1                 NaN           NaN
# 6740                              9p13.1                 NaN           NaN
# 6746                             9q21.11                 NaN           NaN
# 6748                                9q13                 NaN           NaN
# ...                                  ...                 ...           ...
# 38424                             1p34.1                 NaN     NR_001457
# 38483                             1q25.1            AF141346     NR_003944
# 38512                             1p35.2            AY349604     NR_004054
# 38513                             1p35.2                 NaN     NR_033295
# 38650                              20p13            AM413030     NR_003684
# 38844                             1q21.1                 NaN           NaN
# 38845                             1q21.1                 NaN           NaN
# 40136                            12p13.2                 NaN           NaN
# 41136                               2p21                 NaN  NM_001145051
# 41622                            14q11.2              X05775     NG_001332
# 41783     7q34 alternate reference locus    L36092, KI270803     NG_001333
# 41786     7q34 alternate reference locus    U07978, KI270803     NG_001333
# 41794     7q34 alternate reference locus              L36092     NG_001333
# 41797     7q34 alternate reference locus    U07978, KI270803     NG_001333
# 41803     7q34 alternate reference locus    X61447, KI270803     NG_001333
# 41811     7q34 alternate reference locus    M11953, KI270803     NG_001333
# 43113                             3q21.3            BC130546  NM_001039783
# 43182                            17p11.2              X07499           NaN
# 43882                           6p22-p21                 NaN     NG_015634
# 43986                             9p11.1                 NaN     NG_006056
# 43991                            19p13.3                 NaN     NG_006060
# 44139                                19p                 NaN           NaN
# 44172                            18q12.1            BC059403           NaN
# 44381                            Xp11.22                 NaN           NaN
# 44382                            Xp11.22                 NaN           NaN
# 44383                            Xp11.22                 NaN           NaN
# 44497                            16p11.2              Y17508           NaN
# 44553                              17q12                 NaN           NaN
# 45067                            16p13.3                 NaN     NR_024166
# 45596                           19q13.41            AK128250     XR_040819
#
#        Entrez Gene ID(supplied by NCBI) RefSeq(supplied by NCBI)  \
# 725                            285116.0                NR_077058
# 729                            340844.0                NG_022175
# 1143                        100874392.0                NR_046228
# 1145                        100533719.0                NG_028834
# 1668                           644100.0             NM_001195581
# 1842                        100873794.0                NG_032287
# 2113                        100422505.0                NG_025483
# 2300                            85316.0                NM_182484
# 2622                           414763.0                NR_073459
# 2624                            96610.0                NR_027293
# 2759                            23629.0                NR_002730
# 2968                           574037.0                      NaN
# 3111                        100293534.0             NM_001242823
# 3463                           145195.0                      NaN
# 3513                           388289.0                NM_207385
# 4098                           645158.0                NR_033754
# 4126                        100507056.0                NR_108049
# 4314                             6349.0                NM_021006
# 4318                           388372.0                NM_207007
# 5768                            84342.0                NM_032382
# 5861                            53844.0                NR_024086
# 5975                           114657.0                NG_001300
# 6123                           285464.0                NM_175918
# 6284                                NaN                      NaN
# 6285                           642288.0                NG_012729
# 6451                           644021.0                NG_016830
# 6738                        107403068.0                NG_046788
# 6740                        107133499.0                NG_046657
# 6746                        100132340.0                NG_031982
# 6748                        107457588.0                NG_046836
# ...                                 ...                      ...
# 38424                           94163.0                NR_001457
# 38483                          692198.0                NR_003944
# 38512                          692234.0                NR_004054
# 38513                          692235.0                NR_033295
# 38650                       100113378.0                NR_003684
# 38844                       100419019.0                NG_026981
# 38845                       100419020.0                NG_026982
# 40136                          448991.0                NG_004701
# 41136                          388946.0             NM_001145051
# 41622                           28740.0                NG_001332
# 41783                           28618.0                NG_001333
# 41786                           28615.0                NG_001333
# 41794                           28607.0                NG_001333
# 41797                           28604.0                NG_001333
# 41803                           28598.0                NG_001333
# 41811                           28590.0                NG_001333
# 43113                          645840.0             NM_001039783
# 43182                           23666.0                      NaN
# 43882                          387320.0                NG_015634
# 43986                       100033395.0                NG_006056
# 43991                       100033399.0                NG_006060
# 44139                          375690.0                NR_033266
# 44172                          441818.0                NR_003558
# 44381                               NaN                      NaN
# 44382                               NaN                      NaN
# 44383                               NaN                      NaN
# 44497                          440359.0                NR_027011
# 44553                               NaN                      NaN
# 45067                           81854.0                NR_024166
# 45596                          390963.0                NR_073396
#
#       UniProt ID(supplied by UniProt) Ensembl ID(supplied by Ensembl)
# 725                               NaN                             NaN
# 729                               NaN                             NaN
# 1143                           Q8NF67                             NaN
# 1145                              NaN                             NaN
# 1668                           P0DKL9                             NaN
# 1842                              NaN                             NaN
# 2113                              NaN                             NaN
# 2300                           Q86Y27                             NaN
# 2622                              NaN                             NaN
# 2624                              NaN                             NaN
# 2759                              NaN                             NaN
# 2968                           Q5TEV5                             NaN
# 3111                           P0C0L5                             NaN
# 3463                           Q96I85                             NaN
# 3513                           Q6ZP98                             NaN
# 4098                              NaN                             NaN
# 4126                              NaN                             NaN
# 4314                           P16619                             NaN
# 4318                           Q8NHW4                             NaN
# 5768                           Q96MW5                             NaN
# 5861                              NaN                             NaN
# 5975                              NaN                             NaN
# 6123                           Q8N1N5                             NaN
# 6284                              NaN                             NaN
# 6285                              NaN                             NaN
# 6451                              NaN                             NaN
# 6738                              NaN                             NaN
# 6740                              NaN                             NaN
# 6746                              NaN                             NaN
# 6748                              NaN                             NaN
# ...                               ...                             ...
# 38424                             NaN                             NaN
# 38483                             NaN                             NaN
# 38512                             NaN                             NaN
# 38513                             NaN                             NaN
# 38650                             NaN                             NaN
# 38844                             NaN                             NaN
# 38845                             NaN                             NaN
# 40136                             NaN                             NaN
# 41136                          A6NEH6                             NaN
# 41622                             NaN                             NaN
# 41783                             NaN                             NaN
# 41786                             NaN                             NaN
# 41794                             NaN                             NaN
# 41797                             NaN                             NaN
# 41803                             NaN                             NaN
# 41811                             NaN                             NaN
# 43113                          Q6F5E7                             NaN
# 43182                             NaN                             NaN
# 43882                             NaN                             NaN
# 43986                             NaN                             NaN
# 43991                             NaN                             NaN
# 44139                             NaN                             NaN
# 44172                             NaN                             NaN
# 44381                          Q9HD64                             NaN
# 44382                          Q9HD64                             NaN
# 44383                          Q9HD64                             NaN
# 44497                             NaN                             NaN
# 44553                             NaN                             NaN
# 45067                             NaN                             NaN
# 45596                          Q6ZRF7                             NaN
#
# [222 rows x 13 columns]

# %%
# TODO: check synonyms

# %%
# check mskcc isoforms if they provide solutions for the 2K
mskcc = pd.read_csv('../data/isoform_overrides_at_mskcc.txt', sep='\t')
len(mskcc[mskcc.gene_name.isin(multiple_ensembl)])
# Out:
# 21

# %%
uniprot = pd.read_csv('../data/isoform_overrides_uniprot.txt', sep='\t')
len(uniprot[uniprot.gene_name.isin(multiple_ensembl)])
# Out:
# 1024

# %%
hugo[pd.isnull(hugo['Ensembl ID(supplied by Ensembl)'])].Status.value_counts()
# Out:
# Approved            4056
# Symbol Withdrawn    3268
# Entry Withdrawn     1167
# Name: Status, dtype: int64

# %%
hugo_approved_missing_ensembl_id = hugo[pd.isnull(hugo['Ensembl ID(supplied by Ensembl)']) & (hugo.Status == "Approved")]

# %%
print("There are genes in ensembl transcript for {}".format((hugo_approved_missing_ensembl_id['Approved Symbol'].isin(set(et.hgnc_symbol.unique()))).sum()))
# Out:
# There are genes in ensembl transcript for 222

# %%
hugo_approved_missing_eid = hugo_approved_missing_ensembl_id[~(hugo_approved_missing_ensembl_id['Approved Symbol'].isin(set(et.hgnc_symbol.unique())))]

# %%
len(hugo_approved_missing_eid)
# Out:
# 3834

# %% [markdown]
# See also [gdocs](https://docs.google.com/spreadsheets/d/12o3OhlT-K0XQHW6T_kRxCaWIwwUyYlUY5OZkQP9wwns/edit#gid=0)
#
# so i looked at some of those genes, but basically a lot of them don't have genomic coordinates in genecards for whatever reason. Some are e.g. not on the reference assembly or on some alternate reference locus.
#
# I was able to find genomic coordinates for this one http://www.genecards.org/Search/Keyword?queryString=ZNF726P1 and look at vep output. But all the geneids outputted by vep are different:
# http://rest.ensembl.org/vep/human/hgvs/19:g.23832282-23832470A%3EC?content-type=application/json
#
# also using xrefs endpoint from ensembl gives nothing:
# http://rest.ensembl.org/xrefs/symbol/homo_sapiens/ZNF726P1?content-type=application/json
#
# so yeah it seems these genes are all not super important
#
# # Validating canonical output

# %%
can = pd.read_csv("../export/ensembl_biomart_canonical_transcripts_per_hgnc.txt", sep="\t")

# %%
# check if all canonical transcripts are in the ensembl data dump
all_transcripts_in_dump = set(et.transcript_stable_id.unique())
can['mskcc_not_in_dump'] = can.mskcc_canonical_transcript.apply(lambda x: not pd.isnull(x) and x not in all_transcripts_in_dump)
can['uniprot_not_in_dump'] = can.uniprot_canonical_transcript.apply(lambda x: not pd.isnull(x) and x not in all_transcripts_in_dump)
print("Missing mskcc transcripts from dump: {}".format((can.mskcc_not_in_dump & (can.uniprot_canonical_transcript != can.mskcc_canonical_transcript)).sum()))
print("Missing uniprot transcripts from dump: {}".format((can.uniprot_not_in_dump).sum()))
can['ensembl_not_in_dump'] = can.ensembl_canonical_transcript.apply(lambda x: not pd.isnull(x) and x not in all_transcripts_in_dump)
print("Missing ensembl transcripts from dump (should be none): {}".format(can.ensembl_not_in_dump.sum()))
can[can.uniprot_not_in_dump].to_clipboard(index=False)
# Out:
# Missing mskcc transcripts from dump: 0
# Missing uniprot transcripts from dump: 308
# Missing ensembl transcripts from dump (should be none): 0

# %% [markdown]
# Added these to [gdocs](https://docs.google.com/spreadsheets/d/12o3OhlT-K0XQHW6T_kRxCaWIwwUyYlUY5OZkQP9wwns/edit#gid=0). We could handle in genome nexus backend by returning ensembl_canonical_transcript when missing or on frontend.

# %%
# check if all canonical genes are in the ensembl data dump
all_ensembl_genes_in_dump = set(et.gene_stable_id.unique())
can['canonical_gene_in_dump'] = can.ensembl_canonical_gene.apply(lambda x: not pd.isnull(x) and x not in all_ensembl_genes_in_dump)
print("Missing ensembl genes from dump (should be none): {}".format(can.canonical_gene_in_dump.sum()))
# Out:
# Missing ensembl genes from dump (should be none): 0

# %% [markdown]
# # Propose new uniprot ids for hg19

# %%
uniprot = pd.read_csv("../data/isoform_overrides_uniprot.txt",sep="\t")

# %%
uniprot.columns
# Out:
# Index(['enst_id', 'gene_name', 'refseq_id', 'ccds_id'], dtype='object')

# %%
unimerge = pd.merge(uniprot, 
                         can["hgnc_symbol uniprot_not_in_dump uniprot_canonical_transcript ensembl_canonical_transcript".split()],
                         how='left',
                         left_on=['gene_name'],
                         right_on=['hgnc_symbol'],
                         )

# %%
print("Some uniprot entries hugo symbol don't match, because using old hugo symbols: {}".format(
    unimerge.hgnc_symbol.isnull().sum())
)
print("Could fix this by mapping to approved symbols, but not important for this purpose since all those are in dump")
assert(len(unimerge[unimerge.hgnc_symbol.isnull() & unimerge.uniprot_not_in_dump]) == 0)
# Out:
# Some uniprot entries hugo symbol don't match, because using old hugo symbols: 263
# Could fix this by mapping to approved symbols, but not important for this purpose since all those are in dump

# %%
unimerge.columns
# Out:
# Index(['enst_id', 'gene_name', 'refseq_id', 'ccds_id', 'hgnc_symbol',
#        'uniprot_not_in_dump', 'uniprot_canonical_transcript',
#        'ensembl_canonical_transcript'],
#       dtype='object')

# %%
criteria = (~unimerge.hgnc_symbol.isnull()) & unimerge.uniprot_not_in_dump & (~unimerge.ensembl_canonical_transcript.isnull())
unimerge.loc[criteria, ['enst_id']] = unimerge.loc[criteria]['ensembl_canonical_transcript']

# %%
len(unimerge[criteria])
# Out:
# 281

# %%
# assume order is still the same as source overrides file
assert((uniprot.gene_name != unimerge.gene_name).sum() == 0)

# %%
unimerge[uniprot.columns].to_csv("../data/isoform_overrides_uniprot.hg19.txt",index=False,sep="\t")
